# %%
import pandas as pd
df1=pd.read_csv("D:\\Practice\\Data Science\\py\\newYork-weather.csv")
df1
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            1.8      10.0       3.3   5.1     rain
# 1     2012-01-02            0.0      10.0       0.6   8.7      sun
# 2     2012-01-03            0.0       0.6      -8.9   8.2      sun
# 3     2012-01-04            0.0      -1.7     -10.6   5.5      sun
# 4     2012-01-05            0.0       5.6      -3.3   5.4      sun
# 5     2012-01-06            0.0      12.2       0.0   4.6      sun
# 6     2012-01-07            0.0      16.1       2.2   4.7      sun
# 7     2012-01-08            0.0       8.9       0.6   6.2      sun
# 8     2012-01-09            0.0       3.9      -1.7   2.7      sun
# 9     2012-01-10            0.0       8.9      -1.1   5.5  drizzle
# 10    2012-01-11            3.0       8.3      -0.6   3.6     rain
# 11    2012-01-12           22.9       9.4       5.6   6.1     rain
# 12    2012-01-13            0.0      10.0      -1.7  11.4     snow
# ...

# %%
df1['temp_max'].max()
# Out:
# 37.8

# %%
df1['date'][df1['weather']=='sun']
# Out:
# 1       2012-01-02
# 2       2012-01-03
# 3       2012-01-04
# 4       2012-01-05
# 5       2012-01-06
# 6       2012-01-07
# 7       2012-01-08
# 8       2012-01-09
# 14      2012-01-15
# 17      2012-01-18
# 18      2012-01-19
# 19      2012-01-20
# 21      2012-01-22
# 24      2012-01-25
# 27      2012-01-28
# 28      2012-01-29
# 29      2012-01-30
# 30      2012-01-31
# 32      2012-02-02
# 33      2012-02-03
# 34      2012-02-04
# 35      2012-02-05
# 36      2012-02-06
# 37      2012-02-07
# 43      2012-02-13
# 49      2012-02-19
# 50      2012-02-20
# 51      2012-02-21
# 53      2012-02-23
# 56      2012-02-26
#            ...
# 1399    2015-10-31
# 1400    2015-11-01
# 1401    2015-11-02
# 1406    2015-11-07
# 1407    2015-11-08
# 1408    2015-11-09
# 1412    2015-11-13
# 1413    2015-11-14
# 1414    2015-11-15
# 1415    2015-11-16
# 1416    2015-11-17
# 1417    2015-11-18
# 1420    2015-11-21
# 1421    2015-11-22
# 1422    2015-11-23
# 1423    2015-11-24
# ...

# %%
df1.fillna(0,inplace=True)
df1['wind'].mean()
# Out:
# 4.9611225188227195

# %% [markdown]
# df1

# %%
df1
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            1.8      10.0       3.3   5.1     rain
# 1     2012-01-02            0.0      10.0       0.6   8.7      sun
# 2     2012-01-03            0.0       0.6      -8.9   8.2      sun
# 3     2012-01-04            0.0      -1.7     -10.6   5.5      sun
# 4     2012-01-05            0.0       5.6      -3.3   5.4      sun
# 5     2012-01-06            0.0      12.2       0.0   4.6      sun
# 6     2012-01-07            0.0      16.1       2.2   4.7      sun
# 7     2012-01-08            0.0       8.9       0.6   6.2      sun
# 8     2012-01-09            0.0       3.9      -1.7   2.7      sun
# 9     2012-01-10            0.0       8.9      -1.1   5.5  drizzle
# 10    2012-01-11            3.0       8.3      -0.6   3.6     rain
# 11    2012-01-12           22.9       9.4       5.6   6.1     rain
# 12    2012-01-13            0.0      10.0      -1.7  11.4     snow
# ...
