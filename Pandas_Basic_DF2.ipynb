# %%
import pandas as pd
import numpy as np
df=pd.read_csv("newYork-weather.csv")
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     01-01-2012            1.8    9999.0       3.3   5.1     rain
# 1     02-01-2012            0.0      10.0    9999.0   8.7      sun
# 2     03-01-2012            0.0       0.6      -8.9   8.2      sun
# 3     04-01-2012            0.0      -1.7     -10.6   5.5      sun
# 4     05-01-2012            0.0       5.6      -3.3   5.4      sun
# 5     06-01-2012            0.0      12.2       0.0   4.6      sun
# 6     07-01-2012            0.0      16.1       2.2   4.7      sun
# 7     08-01-2012            0.0       8.9       0.6   6.2      sun
# 8     09-01-2012            0.0       3.9      -1.7   2.7      sun
# 9     10-01-2012            0.0       8.9      -1.1   5.5  drizzle
# 10    11-01-2012            3.0       8.3      -0.6   3.6     rain
# 11    12-01-2012           22.9       9.4       5.6   6.1     rain
# 12    13-01-2012            0.0      10.0      -1.7  11.4     snow
# ...

# %%
new_df=df.replace(9999,np.NaN)
new_df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     01-01-2012            1.8       NaN       3.3   5.1     rain
# 1     02-01-2012            0.0      10.0       NaN   8.7      sun
# 2     03-01-2012            0.0       0.6      -8.9   8.2      sun
# 3     04-01-2012            0.0      -1.7     -10.6   5.5      sun
# 4     05-01-2012            0.0       5.6      -3.3   5.4      sun
# 5     06-01-2012            0.0      12.2       0.0   4.6      sun
# 6     07-01-2012            0.0      16.1       2.2   4.7      sun
# 7     08-01-2012            0.0       8.9       0.6   6.2      sun
# 8     09-01-2012            0.0       3.9      -1.7   2.7      sun
# 9     10-01-2012            0.0       8.9      -1.1   5.5  drizzle
# 10    11-01-2012            3.0       8.3      -0.6   3.6     rain
# 11    12-01-2012           22.9       9.4       5.6   6.1     rain
# 12    13-01-2012            0.0      10.0      -1.7  11.4     snow
# ...

# %%
new_df1=df.replace([9999,5999],np.NaN)
new_df1
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     01-01-2012            1.8       NaN       3.3   5.1     rain
# 1     02-01-2012            0.0      10.0       NaN   8.7      sun
# 2     03-01-2012            0.0       0.6      -8.9   8.2      sun
# 3     04-01-2012            0.0      -1.7     -10.6   5.5      sun
# 4     05-01-2012            0.0       5.6      -3.3   5.4      sun
# 5     06-01-2012            0.0      12.2       0.0   4.6      sun
# 6     07-01-2012            0.0      16.1       2.2   4.7      sun
# 7     08-01-2012            0.0       8.9       0.6   6.2      sun
# 8     09-01-2012            0.0       3.9      -1.7   2.7      sun
# 9     10-01-2012            0.0       8.9      -1.1   5.5  drizzle
# 10    11-01-2012            3.0       8.3      -0.6   3.6     rain
# 11    12-01-2012           22.9       9.4       5.6   6.1     rain
# 12    13-01-2012            0.0      10.0      -1.7  11.4     snow
# ...

# %%
new_df2= df.replace({'temp_min':'[A-Za-z]','wind':'[A-Za-z]'},"",regex=True)
new_df2
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     01-01-2012            1.8    9999.0       3.3   5.1     rain
# 1     02-01-2012            0.0      10.0    9999.0   8.7      sun
# 2     03-01-2012            0.0       0.6      -8.9   8.2      sun
# 3     04-01-2012            0.0      -1.7     -10.6   5.5      sun
# 4     05-01-2012            0.0       5.6      -3.3   5.4      sun
# 5     06-01-2012            0.0      12.2       0.0   4.6      sun
# 6     07-01-2012            0.0      16.1       2.2   4.7      sun
# 7     08-01-2012            0.0       8.9       0.6   6.2      sun
# 8     09-01-2012            0.0       3.9      -1.7   2.7      sun
# 9     10-01-2012            0.0       8.9      -1.1   5.5  drizzle
# 10    11-01-2012            3.0       8.3      -0.6   3.6     rain
# 11    12-01-2012           22.9       9.4       5.6   6.1     rain
# 12    13-01-2012            0.0      10.0      -1.7  11.4     snow
# ...
