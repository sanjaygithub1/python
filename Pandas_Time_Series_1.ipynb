# %%
import pandas as pd
df = pd.read_csv("applestock.csv")
df
# Out:
#           Date     Open      High       Low   Close    Volume
# 0   29-08-2019  208.500  209.3200  206.6550  209.01  21007650
# 1   28-08-2019  204.100  205.7200  203.3200  205.53  15957630
# 2   27-08-2019  207.860  208.5500  203.5300  204.16  25897340
# 3   26-08-2019  205.860  207.1900  205.0573  206.49  26066130
# 4   23-08-2019  209.430  212.0510  201.0000  202.64  46882840
# 5   22-08-2019  213.190  214.4350  210.7500  212.46  22267820
# 6   21-08-2019  212.990  213.6500  211.6032  212.64  21564750
# 7   20-08-2019  210.880  213.3500  210.3200  210.36  26919530
# 8   19-08-2019  210.620  212.7307  210.0250  210.35  24431920
# 9   16-08-2019  204.280  207.1600  203.8400  206.50  28813620
# 10  15-08-2019  203.460  205.1400  199.6700  201.74  27883360
# 11  14-08-2019  203.160  206.4400  202.5869  202.75  36547440
# 12  13-08-2019  201.020  212.1400  200.8300  208.97  47539790
# 13  12-08-2019  199.620  202.0516  199.1500  200.48  22481890
# ...

# %%
rng=pd.date_range(start="29-05-2019",end="29-08-2019",freq='B')
rng
# Out:
# DatetimeIndex(['2019-05-29', '2019-05-30', '2019-05-31', '2019-06-03',
#                '2019-06-04', '2019-06-05', '2019-06-06', '2019-06-07',
#                '2019-06-10', '2019-06-11', '2019-06-12', '2019-06-13',
#                '2019-06-14', '2019-06-17', '2019-06-18', '2019-06-19',
#                '2019-06-20', '2019-06-21', '2019-06-24', '2019-06-25',
#                '2019-06-26', '2019-06-27', '2019-06-28', '2019-07-01',
#                '2019-07-02', '2019-07-03', '2019-07-04', '2019-07-05',
#                '2019-07-08', '2019-07-09', '2019-07-10', '2019-07-11',
#                '2019-07-12', '2019-07-15', '2019-07-16', '2019-07-17',
#                '2019-07-18', '2019-07-19', '2019-07-22', '2019-07-23',
#                '2019-07-24', '2019-07-25', '2019-07-26', '2019-07-29',
#                '2019-07-30', '2019-07-31', '2019-08-01', '2019-08-02',
#                '2019-08-05', '2019-08-06', '2019-08-07', '2019-08-08',
# ...

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
us_bd = CustomBusinessDay(calendar=USFederalHolidayCalendar())
rng=pd.date_range(start="29-05-2019",end="29-08-2019",freq=us_bd)
rng
# Out:
# DatetimeIndex(['2019-05-29', '2019-05-30', '2019-05-31', '2019-06-03',
#                '2019-06-04', '2019-06-05', '2019-06-06', '2019-06-07',
#                '2019-06-10', '2019-06-11', '2019-06-12', '2019-06-13',
#                '2019-06-14', '2019-06-17', '2019-06-18', '2019-06-19',
#                '2019-06-20', '2019-06-21', '2019-06-24', '2019-06-25',
#                '2019-06-26', '2019-06-27', '2019-06-28', '2019-07-01',
#                '2019-07-02', '2019-07-03', '2019-07-05', '2019-07-08',
#                '2019-07-09', '2019-07-10', '2019-07-11', '2019-07-12',
#                '2019-07-15', '2019-07-16', '2019-07-17', '2019-07-18',
#                '2019-07-19', '2019-07-22', '2019-07-23', '2019-07-24',
#                '2019-07-25', '2019-07-26', '2019-07-29', '2019-07-30',
#                '2019-07-31', '2019-08-01', '2019-08-02', '2019-08-05',
#                '2019-08-06', '2019-08-07', '2019-08-08', '2019-08-09',
# ...

# %%
df.set_index(rng,inplace=True)
df
# Out:
#                   Date     Open      High       Low   Close    Volume
# 2019-05-29  29-08-2019  208.500  209.3200  206.6550  209.01  21007650
# 2019-05-30  28-08-2019  204.100  205.7200  203.3200  205.53  15957630
# 2019-05-31  27-08-2019  207.860  208.5500  203.5300  204.16  25897340
# 2019-06-03  26-08-2019  205.860  207.1900  205.0573  206.49  26066130
# 2019-06-04  23-08-2019  209.430  212.0510  201.0000  202.64  46882840
# 2019-06-05  22-08-2019  213.190  214.4350  210.7500  212.46  22267820
# 2019-06-06  21-08-2019  212.990  213.6500  211.6032  212.64  21564750
# 2019-06-07  20-08-2019  210.880  213.3500  210.3200  210.36  26919530
# 2019-06-10  19-08-2019  210.620  212.7307  210.0250  210.35  24431920
# 2019-06-11  16-08-2019  204.280  207.1600  203.8400  206.50  28813620
# 2019-06-12  15-08-2019  203.460  205.1400  199.6700  201.74  27883360
# 2019-06-13  14-08-2019  203.160  206.4400  202.5869  202.75  36547440
# ...

# %%
us_bd = CustomBusinessDay(calendar=USFederalHolidayCalendar())
rng=pd.date_range(start="29-05-2019",end="29-08-2019",freq=us_bd)
rng
# Out:
# DatetimeIndex(['2019-05-29', '2019-05-30', '2019-05-31', '2019-06-03',
#                '2019-06-04', '2019-06-05', '2019-06-06', '2019-06-07',
#                '2019-06-10', '2019-06-11', '2019-06-12', '2019-06-13',
#                '2019-06-14', '2019-06-17', '2019-06-18', '2019-06-19',
#                '2019-06-20', '2019-06-21', '2019-06-24', '2019-06-25',
#                '2019-06-26', '2019-06-27', '2019-06-28', '2019-07-01',
#                '2019-07-02', '2019-07-03', '2019-07-05', '2019-07-08',
#                '2019-07-09', '2019-07-10', '2019-07-11', '2019-07-12',
#                '2019-07-15', '2019-07-16', '2019-07-17', '2019-07-18',
#                '2019-07-19', '2019-07-22', '2019-07-23', '2019-07-24',
#                '2019-07-25', '2019-07-26', '2019-07-29', '2019-07-30',
#                '2019-07-31', '2019-08-01', '2019-08-02', '2019-08-05',
#                '2019-08-06', '2019-08-07', '2019-08-08', '2019-08-09',
# ...

# %%
# %matplotlib inline 
df.Close.plot()

# %%
df["2019-05-29":"2019-06-10"].Close.mean()
# Out:
# 208.1822222222222

# %%
df.asfreq('D',method='pad')
# Out:
#                   Date     Open      High       Low   Close    Volume
# 2019-05-29  29-08-2019  208.500  209.3200  206.6550  209.01  21007650
# 2019-05-30  28-08-2019  204.100  205.7200  203.3200  205.53  15957630
# 2019-05-31  27-08-2019  207.860  208.5500  203.5300  204.16  25897340
# 2019-06-01  27-08-2019  207.860  208.5500  203.5300  204.16  25897340
# 2019-06-02  27-08-2019  207.860  208.5500  203.5300  204.16  25897340
# 2019-06-03  26-08-2019  205.860  207.1900  205.0573  206.49  26066130
# 2019-06-04  23-08-2019  209.430  212.0510  201.0000  202.64  46882840
# 2019-06-05  22-08-2019  213.190  214.4350  210.7500  212.46  22267820
# 2019-06-06  21-08-2019  212.990  213.6500  211.6032  212.64  21564750
# 2019-06-07  20-08-2019  210.880  213.3500  210.3200  210.36  26919530
# 2019-06-08  20-08-2019  210.880  213.3500  210.3200  210.36  26919530
# 2019-06-09  20-08-2019  210.880  213.3500  210.3200  210.36  26919530
# ...

# %%
df.asfreq('W',method='pad')
# Out:
#                   Date    Open      High     Low   Close    Volume
# 2019-06-02  27-08-2019  207.86  208.5500  203.53  204.16  25897340
# 2019-06-09  20-08-2019  210.88  213.3500  210.32  210.36  26919530
# 2019-06-16  13-08-2019  201.02  212.1400  200.83  208.97  47539790
# 2019-06-23  06-08-2019  196.31  198.0670  194.04  197.00  35824790
# 2019-06-30  30-07-2019  208.76  210.1600  207.31  208.78  33935720
# 2019-07-07  24-07-2019  207.67  209.1500  207.17  208.67  14991570
# 2019-07-14  17-07-2019  204.05  205.0915  203.27  203.35  14107450
# 2019-07-21  10-07-2019  201.85  203.7300  201.56  203.23  17897140
# 2019-07-28  02-07-2019  201.41  203.1323  201.36  202.73  16935220
# 2019-08-04  25-06-2019  198.43  199.2600  195.29  195.57  21070330
# 2019-08-11  18-06-2019  196.05  200.2900  195.21  198.45  26551000
# 2019-08-18  11-06-2019  194.86  196.0000  193.60  194.81  26932880
# 2019-08-25  04-06-2019  175.44  179.8300  174.52  179.64  30967960

# %%
df.asfreq('M',method='pad')
# Out:
#                   Date    Open    High     Low   Close    Volume
# 2019-05-31  27-08-2019  207.86  208.55  203.53  204.16  25897340
# 2019-06-30  30-07-2019  208.76  210.16  207.31  208.78  33935720
# 2019-07-31  27-06-2019  200.29  201.57  199.57  199.74  20899720
